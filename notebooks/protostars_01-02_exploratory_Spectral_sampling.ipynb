# %% [markdown]
# # Protostars
# ## 01- Exploratory Data Analysis
# ### II.  Spectral sampling
#
# Here we calculate the spectral sampling and verify the spectral resolution, while spot checking the spectrum.
#
# Michael Gully-Santiago
# February 21, 2017

# %% [markdown]
# Let's see how many pixels per resolution element.

# %%
import pandas as pd
import astropy
from astropy.io import ascii

# %%
dat = pd.read_csv('../data/spectra/S68N_2014Jun_noemis.txt', delim_whitespace=True, names=['wavelength_A', 'flux'])
dat.head()
# Out:
#    wavelength_A      flux
# 0  20601.230469  4609.675
# 1  20605.507227  4834.167
# 2  20609.783986  4523.667
# 3  20614.060745  4712.858
# 4  20618.337503  4790.297

# %%
plt.step(dat.wavelength_A, dat.flux)

# %%
dat.wavelength_A.min(), dat.wavelength_A.max()
# Out:
# (20601.230468750102, 24599.999825954503)

# %%
plt.step(dat.wavelength_A, dat.flux)
plt.xlim(23000, 23500)
plt.ylim(9000, 14000)
# Out:
# (9000, 14000)

# %% [markdown]
# Hmm... so from the previous notebook, $R = \frac{\lambda}{\Delta \lambda} \sim 1250$, so at $\lambda = 2.3 ~\mu$m, we have $\Delta \lambda$:

# %%
delta_lambda = 23000.0/1250.0
delta_lambda
# Out:
# 18.4

# %% [markdown]
# So 18.4 Angstroms over a $0.76''$ slit, so about:

# %%
7.5/45000.0*1250.0
# Out:
# 0.20833333333333331

# %%
18.4/0.76
# Out:
# 24.210526315789473

# %% [markdown]
# 24.2 Angstroms per arcsecond.  Times the $0.193''/$pixel platescale we get:

# %%
24.2 * 0.193
# Out:
# 4.6706

# %% [markdown]
# 4.67 Angstroms per pixel, with:

# %%
0.76/0.193
# Out:
# 3.937823834196891

# %% [markdown]
# About 3.9 pixels per slit sampling.

# %% [markdown]
# *All done!*
