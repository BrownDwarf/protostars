# %% [markdown]
# # protostars
# ## 06- Av and scattering
# ### I. Exploratory
#
# Spot check
#
# gully
# April 13, 2017

# %% [markdown]
# Here is what the Chebyshev polynomials look like.  It's not clear if these are sufficient to mimic the effect of extinction.  Extinction is typically defined as a power law.

# %%
from numpy.polynomial import Chebyshev as Ch

# %%
c3 = Ch([0, 0.02, 0.01, -0.02])

# %%
x = np.arange(0, 1, 0.01)

# %%
plt.step(x, c3(x))

# %% [markdown]
# The model flexibility allows there to be non-monotonic extinction, which doesn't make sense...
